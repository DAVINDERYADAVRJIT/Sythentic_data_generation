# %%
from data_distribution_n import find_distributions
import pandas as pd
df = pd.read_csv('./data/churn.csv')

df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
find_distributions(df, top_n=3)
# Out:
#              feature         data_type best_distribution  \
# 0         customerID  categorical/text       Categorical
# 1             gender  categorical/text       Categorical
# 2      SeniorCitizen            binary         bernoulli
# 3            Partner  categorical/text       Categorical
# 4         Dependents  categorical/text       Categorical
# 5             tenure    discrete_count         geometric
# 6       PhoneService  categorical/text       Categorical
# 7      MultipleLines  categorical/text       Categorical
# 8    InternetService  categorical/text       Categorical
# 9     OnlineSecurity  categorical/text       Categorical
# 10      OnlineBackup  categorical/text       Categorical
# 11  DeviceProtection  categorical/text       Categorical
# 12       TechSupport  categorical/text       Categorical
# 13       StreamingTV  categorical/text       Categorical
# 14   StreamingMovies  categorical/text       Categorical
# ...
